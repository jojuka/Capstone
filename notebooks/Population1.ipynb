# %% [markdown]
# **Import Libraries

# %%
from bs4 import BeautifulSoup #as bs
import requests
import pandas as pd
import numpy as np
import re

# %% [markdown]
# **Create a URL object and page request

# %%
website_url = 'https://www.disabled-world.com/calculators-charts/wpc.php'
response = requests.get(website_url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><title>World Population Chart for Countries and Continents | Disabled World</title><meta name="description" content="Information and statistical chart showing population of countries around the world including statistics table of the most populated continents"><script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1372083601437131" crossorigin="anonymous"></script><link rel="canonical" href="https://www.disabled-world.com/calculators-charts/wpc.php"><meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1"><style>html{overflow-y:scroll;scroll-behavior:smooth;box-sizing:border-box;background:#f8f9f4;scroll-padding-top:92px}body{width:100%;max-width:1024px;margin:0 auto;line-height:135%;color:#000;overflow-wrap:break-word;-webkit-hyphens:auto;-moz-hyph
# ...

# %% [markdown]
# **Page Permissions
#
# User-agent: Mediapartners-Google
# Disallow:
#
# User-agent: *
#
# Disallow: /includes/*
# Disallow: /reports/*
# Disallow: /doubleclick/*
# Disallow: /*/categorySimArt.php
# Disallow: /*/include_categoryMenu.php
# Disallow: /*/include_categoryBreadcrumb.php
# Disallow: /pics/unsavedUploadExpiryTimes.dat
#
# User-agent: newspaper/0.2.8
# Disallow: /
#
# Sitemap: https://www.disabled-world.com/rss.xml
# Sitemap: https://www.disabled-world.com/feeds/news.xml
# Sitemap: https://www.disabled-world.com/feeds/pdf-sitemap.txt
# Sitemap: https://www.disabled-world.com/feeds/sitemapindex.xml
# Sitemap: https://www.disabled-world.com/feeds/cat1and2sitemap.txt
# Sitemap: https://www.disabled-world.com/feeds/images_sitemap.xml

# %% [markdown]
# **Get page inofrmation in html versus lxml format

# %%
soup = BeautifulSoup(response.content, 'lxml')
print (soup.title.text)
# Out:
# World Population Chart for Countries and Continents | Disabled World

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    World Population Chart for Countries and Continents | Disabled World
#   </title>
#   <meta content="Information and statistical chart showing population of countries around the world including statistics table of the most populated continents" name="description"/>
#   <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1372083601437131">
#   </script>
#   <link href="https://www.disabled-world.com/calculators-charts/wpc.php" rel="canonical"/>
#   <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
#   <style>
# ...

# %%
continents= soup.find('table', class_='lists')
print (continents.text)
# Out:
# Most Populated Continents (2016)
#
#
# RankContinentPopulation% of World Pop.
#
#
# 1
# Asia
# 4,436,224,000
# 59.69%
#
#
# 2
# Africa
# 1,216,130,000
# 16.36%
#
#
# 3
# Europe(Life Expectancy for U.K. Countries and Regions)
# 738,849,000
# 9.94%
#
#
# 4
# North America
# 579,024,000
# 7.79%
#
#
# 5
# South America
# 422,535,000
# 5.68%
#
#
# 6
# Australia(Life Expectancy by Australian State and Territory)
# 39,901,000
# 0.54%
#
#
# 7
# Antarctica
# 4,490
# 0%

# %%
table= soup.find_all("table", attrs={'class': 'lists'})

# %%
len(table)
# Out:
# 2

# %%
country=pd.read_html(str(table[1]))[0]

# %%
country.head(5)
# Out:
#   World Population Chart by Country (2017)  \
#                                       Rank
# 0                                        1
# 1                                        2
# 2                                        3
# 3                                        4
# 4                                        5
#
#                                                                   \
#                                              Country  Population
# 0                                              China  1388232693
# 1            India(Indian Life Expectancy by States)  1342512706
# 2  United States(Population of American Cities an...   326474013
# 3                                          Indonesia   263510146
# 4                                             Brazil   211243220
#
#                                         \
#   Density (P/Km²) Med. Age World Share
# 0             148       37       0.185
# 1             452       27       0.179
# ...

# %%
pd.read_html(str(table[1]))[0]
# Out:
#     World Population Chart by Country (2017)  \
#                                         Rank
# 0                                          1
# 1                                          2
# 2                                          3
# 3                                          4
# 4                                          5
# ..                                       ...
# 228                                      229
# 229                                      230
# 230                                      231
# 231                                      232
# 232                                      233
#
#                                                                     \
#                                                Country  Population
# 0                                                China  1388232693
# 1              India(Indian Life Expectancy by States)  1342512706
# 2    United States(Population of American Cities an...   326474013
# ...

# %%
import re
country['Country'] = re.sub("\(.*?\)", "", str(country))

# %%
country
# Out:
#     World Population Chart by Country (2017)  \
#                                         Rank
# 0                                          1
# 1                                          2
# 2                                          3
# 3                                          4
# 4                                          5
# ..                                       ...
# 228                                      229
# 229                                      230
# 230                                      231
# 231                                      232
# 232                                      233
#
#                                                                     \
#                                                Country  Population
# 0                                                China  1388232693
# 1              India(Indian Life Expectancy by States)  1342512706
# 2    United States(Population of American Cities an...   326474013
# ...
