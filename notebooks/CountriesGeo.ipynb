# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\jojuk\Documents\git\projects\Capstone\data\SQLCountryInfo.csv")

# %%
df.head()
# Out:
#             Country  SumStudentsExchange  SumNIAdmissions  \
# 0       Afghanistan                 1704            10160
# 1            Tuvalu                   12              540
# 2              Fiji                  412            36631
# 3          Kiribati                  139             2661
# 4  Marshall Islands                    0              656
#
#    percentsetoniadmissions   Latitude   Longitude Unnamed: 6
# 0                       17  34.983000   63.133300        NaN
# 1                        2  -8.516652  179.216647        NaN
# 2                        1 -17.799600  177.416602        NaN
# 3                        5   1.338188  173.017571        NaN
# 4                        0   7.103004  171.380000        NaN

# %%
#df.dropna(axis=1, how= 'all', inplace=False)
df.dropna(how='all', axis=1, inplace=True)

# %%
df
# Out:
#               Country  SumStudentsExchange  SumNIAdmissions  \
# 0         Afghanistan                 1704            10160
# 1              Tuvalu                   12              540
# 2                Fiji                  412            36631
# 3            Kiribati                  139             2661
# 4    Marshall Islands                    0              656
# ..                ...                  ...              ...
# 182            Mexico               617783         61921422
# 183             Samoa                  240             8265
# 184             Tonga                  356            11446
# 185             Total              7631236        240486098
# 186           Unknown                23865           266877
#
#      percentsetoniadmissions   Latitude   Longitude Unnamed: 6
# 0                         17  34.983000   63.133300        NaN
# 1                          2  -8.516652  179.216647        NaN
# 2                          1 -17.799600  177.416602        NaN
# 3                          5   1.338188  173.017571        NaN
# 4                          0   7.103004  171.380000        NaN
# ..                       ...        ...         ...        ...
# 182                        1  23.634501 -102.552788        NaN
# 183                        3 -13.841545 -171.738642        NaN
# 184                        3 -18.649574 -173.983293        NaN
# 185                        3        NaN         NaN        NaN
# 186                        9        NaN         NaN        NaN
#
# [187 rows x 7 columns]

# %%
df['Longitude'].tolist()
# Out:
# [63.13329964,
#  179.2166471,
#  177.4166019,
#  173.0175708,
#  171.3800002,
#  167.1766068,
#  166.9315,
#  158.1499743,
#  156.8350158,
#  151.3000048,
#  143.7180037,
#  134.4695009,
#  133.9170865,
#  127.6897147,
#  125.7620047,
#  125.5794559,
#  123.3800036,
#  121.2988889,
#  114.9332841,
#  106.2000006,
#  106.1469997,
#  104.5189986,
#  103.8558207,
#  100.4127778,
#  100.1899987,
#  98.50007524,
#  97.96899665,
#  97.20600363,
#  89.92003048,
#  89.51670065,
#  82.18330255,
#  81.23300155,
#  75.28459306,
#  73.81800065,
#  73.49994747,
#  70.10082678,
#  69.00000365,
#  63.49899651,
#  59.45165767,
#  57.97820756,
#  57.51663367,
#  56.27779455,
#  55.55334265,
#  55.44998979,
#  51.59400361,
#  51.53296789,
#  50.58305172,
#  50.16659135,
#  47.99999756,
#  46.96773907,
#  45.8161111,
#  45.57400265,
#  44.78300151,
#  44.3591667,
#  43.2402441,
#  43.00000263,
#  42.72999101,
#  42.37200058,
#  39.725799,
#  38.47699862,
#  37.33329653,
#  36.95100363,
#  36.65749345,
#  36.23329852,
#  36.10500351,
#  35.53329652,
#  34.86670252,
#  34.34998572,
#  33.95001013,
#  33.63599757,
#  33.6,
#  32.225,
#  30.97003699,
#  30.89999749,
#  30.51669662,
#  30.2176,
#  29.5667016,
#  29.1608333,
#  29.08002315,
#  28.70199951,
#  28.52800254,
#  27.75300351,
#  27.3165649,
#  27.22599962,
#  26.15200256,
#  26.01344031,
#  24.71900459,
#  24.47199954,
#  24.37002641,
#  23.5413889,
#  23.27400062,
#  22.43400358,
#  21.42999914,
#  43.13799911,
#  60.99699611,
#  55.74002016,
#  58.9430556,
#  45.04500004,
#  38.89899915,
#  -18.01953449,
#  4.320000059,
#  42.6026,
#  53.80003522,
#  41.51899817,
#  46.07001609,
#  48.73329022,
#  44.21997398,
#  47.09099714,
#  9.395001123,
#  -21.43600193,
#  43.7272222,
#  40.64200213,
#  46.54047833,
#  60.61300204,
#  35.89973248,
#  14.4974,
#  50.66299816,
#  -4.164002942,
#  43.91715008,
#  41.90001223,
#  2.152997996,
#  1.449999085,
#  30.1679118,
#  33.399999,
#  13.98740074,
#  47.51669707,
#  47.13372377,
#  4.155003087,
#  58.46475606,
#  49.98247246,
#  5.532003041,
#  1.645002051,
#  43.73964569,
#  47.36999713,
#  49.88330105,
#  36.82199703,
#  4.183298973,
#  50.44599911,
#  6.615000092,
#  42.50000144,
#  9.261000068,
#  12.05499605,
#  7.335998991,
#  16.41699404,
#  38.91200402,
#  8.280000029,
#  4.799996997,
#  53.6333333,
#  40.64100311,
#  8.880425638,
#  12.08400302,
#  22.67900113,
#  13.55100308,
#  12.26899803,
#  64.56950277,
#  16.88376141,
#  -5.809995505,
#  5.599998125,
#  5.900039082,
#  -34.47999901,
#  13.10200258,
#  -22.03000205,
#  14.00197349,
#  13.14827883,
#  15.30101564,
#  10.28046166,
#  12.0526334,
#  17.11803652,
#  17.30203046,
#  -17.55000242,
#  9.657999007,
#  19.50499807,
#  -52.64997882,
#  -51.65003986,
#  5.346999095,
#  18.63393473,
#  -1.483002014,
#  18.44299809,
#  26.53327578,
#  21.83999636,
#  9.541686355,
#  -6.629997133,
#  9.991997986,
#  13.47599712,
#  15.05999711,
#  17.15599807,
#  13.91900399,
#  15.10299903,
#  50.15002545,
#  23.634501,
#  -13.84154504,
#  -18.64957355,
#  nan,
#  nan]

# %%
df['Coordinates'] = list(zip(df.Longitude, df.Latitude))

# %%
df['Coordinates'] = df['Coordinates'].apply(Point)

# %%
gdf = gpd.GeoDataFrame(df, geometry='Coordinates')

# %%
print(gdf.head())
# Out:
#             Country  SumStudentsExchange  SumNIAdmissions  \
# 0       Afghanistan                 1704            10160
# 1            Tuvalu                   12              540
# 2              Fiji                  412            36631
# 3          Kiribati                  139             2661
# 4  Marshall Islands                    0              656
#
#    percentsetoniadmissions   Latitude   Longitude Unnamed: 6  \
# 0                       17  34.983000   63.133300        NaN
# 1                        2  -8.516652  179.216647        NaN
# 2                        1 -17.799600  177.416602        NaN
# 3                        5   1.338188  173.017571        NaN
# 4                        0   7.103004  171.380000        NaN
#
#                    Coordinates
# 0    POINT (63.13330 34.98300)
# 1   POINT (179.21665 -8.51665)
# 2  POINT (177.41660 -17.79960)
# 3    POINT (173.01757 1.33819)
# 4    POINT (171.38000 7.10300)

# %%
world = gpd.read_file('../data/world.json')

# %%
ax=world.plot(figsize=(20,16) )#color='8BB5D9'
gdf.plot(ax=ax, color='#75AB37')

ax.set_title("Countries of Origin for Students and Exchange Visas to U.S., 2017 to 2019")
plt.show()

plt.savefig('Countries of Origin.png')

# %%
plt.savefig('Countries of Origin.png')

# %%
gdf=geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df['Longitude'], df['Latitude']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17076/1162911297.py in <module>
# ----> 1 gdf=geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df['Longitude'], df['Latitude']))
#
# NameError: name 'geopandas' is not defined
